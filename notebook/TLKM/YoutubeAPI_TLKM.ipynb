# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Skripsi
# Out:
# /content/drive/MyDrive/Skripsi

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import pandas as pd
import json
import os
import time
from datetime import datetime
from utils.data_collection import main_youtube

# %%
API_KEY = 'Youtube API 3'
youtube = build('youtube', 'v3', developerKey=API_KEY)
TICKER = 'TLKM'

# %%
output_dir = f'data/{TICKER}/data_collection'

# os.makedirs(output_dir, exist_ok=True)

USED_IDS_FILE = f'{output_dir}/id_tlkm.json'

# %%
query = "Telkomsel"

main_youtube(youtube, USED_IDS_FILE, query, TICKER)
# Out:
# Mencari video dengan query: 'Telkomsel'
# Video yang sudah pernah digunakan: 3111
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# Error saat mencari video: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?q=Telkomsel&part=snippet&type=video&maxResults=50&pageToken=CKwCEAA&relevanceLanguage=id&regionCode=ID&key=AIzaSyDI-78t9GYrXs3m3JvpERmdKoBNnRv5qmg&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# ✅ Ditemukan 1 video baru untuk diproses.
# [1/1] Memproses video ID: 214a5M-94Yk
#   - Title: Akting kagetnya natural sekali, kak #Dita 😂Tonton ...
#   - Channel: Telkomsel
#   - Berhasil mengambil 147 komentar
#
# === RINGKASAN ===
# ...

# %%
df_TLKM = pd.read_csv(f'{output_dir}/youtube_comments_{TICKER}.csv')

# %%
len(df_TLKM)
# Out:
# 224407

# %%
df_TLKM.duplicated().sum()
# Out:
# np.int64(16293)

# %%
df_TLKM
# Out:
#            tanggal                                           sentimen
# 0       2023-05-05                             Makasih bang 100% work
# 1       2023-05-05                                        mantab kaka
# 2       2023-07-15               Ya work lah kartu lu kan kartu sakti
# 3       2023-07-21  @@serbaserbimobildanpenjuala4958 iyaa sebenarn...
# 4       2023-08-14                               ​@@daftar_tutorial😮😮
# ...            ...                                                ...
# 224402  2024-06-25  Itu yg kak Dita main mainan buaya, yg Abang Su...
# 224403  2024-06-25   https://youtu.be/tDkTNeghQi4?si=HGgCfz8y64xgRi6l
# 224404  2024-06-25                                  Yang ada ka maudy
# 224405  2024-06-25                Kapan tayang lagi critnya kangen❤❤❤
# 224406  2024-07-15                               Udah tayang kok bang
#
# [224407 rows x 2 columns]

# %%
df_TLKM[df_TLKM.duplicated(keep=False)].sort_values(by=['tanggal', 'sentimen'])
# Out:
#            tanggal                                           sentimen
# 218461  2011-06-18                                        ngapusi iki
# 218462  2011-06-18                                        ngapusi iki
# 218123  2014-03-20  Jika bnran coll keoperator...\nIcghhh...katro ...
# 218124  2014-03-20  Jika bnran coll keoperator...\nIcghhh...katro ...
# 189102  2015-12-08                        trims.. slm dari halmahera.
# ...            ...                                                ...
# 220175  2025-10-17                        Hati hati penipuan anjinggg
# 216400  2025-10-17                    Kata gua sihh huakkkss😮 cuhhhh🤧
# 216401  2025-10-17                    Kata gua sihh huakkkss😮 cuhhhh🤧
# 215707  2025-10-18  Makasih selalu hadir ya king Moga membantu Dis...
# 218961  2025-10-18  Makasih selalu hadir ya king Moga membantu Dis...
#
# [30042 rows x 2 columns]

# %%
df_TLKM2 = df_TLKM.copy()

df_TLKM2['tanggal'] = pd.to_datetime(df_TLKM2['tanggal'], errors='coerce')

df_TLKM2['tahun'] = df_TLKM2['tanggal'].dt.year

# Hitung jumlah data per tahun
jumlah_per_tahun = df_TLKM2['tahun'].value_counts().sort_index()

# Tampilkan hasil
print(len(df_TLKM2))
print(jumlah_per_tahun)
# Out:
# 224407
# tahun
# 2007        1
# 2009        1
# 2011       67
# 2012      182
# 2013       81
# 2014       37
# 2015      101
# 2016      137
# 2017     3041
# 2018      717
# 2019     1808
# 2020    23164
# 2021    28340
# 2022    20015
# 2023    44472
# 2024    41433
# 2025    60810
# Name: count, dtype: int64
