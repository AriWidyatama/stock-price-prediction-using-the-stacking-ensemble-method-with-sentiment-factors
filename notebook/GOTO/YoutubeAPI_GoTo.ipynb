# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Skripsi
# Out:
# /content/drive/MyDrive/Skripsi

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import pandas as pd
import json
import os
import time
from datetime import datetime
from utils.data_collection import main_youtube

# %%
API_KEY = 'Youtube API 3'
youtube = build('youtube', 'v3', developerKey=API_KEY)
TICKER = 'GOTO'

# %%
output_dir = f'data/{TICKER}/data_collection'

# os.makedirs(output_dir, exist_ok=True)

USED_IDS_FILE = f'{output_dir}/id_goto.json'

# %%
query = "Tokopedia"

main_youtube(youtube, USED_IDS_FILE, query, TICKER)
# Out:
# Mencari video dengan query: '"Tokopedia"'
# Video yang sudah pernah digunakan: 2612
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# Error saat mencari video: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?q=%22Tokopedia%22&part=snippet&type=video&maxResults=50&pageToken=CDIQAA&relevanceLanguage=id&regionCode=ID&key=AIzaSyDk5q2l5pB9VnzG0LFzKXrLGrvxoYBUOK0&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# ❌ Tidak ada video baru ditemukan.

# %%
df_GOTO = pd.read_csv(f'{output_dir}/youtube_comments_{TICKER}.csv')

# %%
len(df_GOTO)
# Out:
# 326959

# %%
df_GOTO.duplicated().sum()
# Out:
# np.int64(22586)

# %%
df_GOTO
# Out:
#           tanggal                                           sentimen
# 0      2023-05-05                             Makasih bang 100% work
# 1      2023-05-05                                        mantab kaka
# 2      2023-07-15               Ya work lah kartu lu kan kartu sakti
# 3      2023-07-21  @@serbaserbimobildanpenjuala4958 iyaa sebenarn...
# 4      2023-08-14                               ​@@daftar_tutorial😮😮
# ...           ...                                                ...
# 99918  2024-12-03  Punya saya ko susah ya yg dikirim berupa link ...
# 99919  2024-11-10  Bang gw mau daftar nomer baru,tapi kok harus v...
# 99920  2024-10-31  Bagaimana caranya untuk logout 1 nomor yang te...
# 99921  2024-10-22  Bang gi mana cara atasi..lain di daptar kan no...
# 99922  2024-10-21  Saya ga bisa tapi nomer baru biss nomer lama m...
#
# [99923 rows x 2 columns]

# %%
df_GOTO[df_GOTO.duplicated(keep=False)].sort_values(by=['tanggal', 'sentimen'])
# Out:
#           tanggal                                           sentimen
# 19351  2017-02-13  +MakinPandai tapi apa ada kemungkinan di.dalem...
# 19356  2017-02-13  +MakinPandai tapi apa ada kemungkinan di.dalem...
# 19353  2017-02-13  +MakinPandai tapi kalo di matahari engga ada d...
# 19358  2017-02-13  +MakinPandai tapi kalo di matahari engga ada d...
# 19899  2017-02-13  +Ronaldo Yonathan Samson Mohon bersabar ini uj...
# ...           ...                                                ...
# 24474  2025-07-13  Lebih kejam mana dengan koruptor/maling uang r...
# 50378  2025-07-13  Saya udah coba....begitu muncul tekan 1,malah ...
# 77484  2025-07-13  Saya udah coba....begitu muncul tekan 1,malah ...
# 56242  2025-07-14  Makasih Kapten selalu hadir semoga membantu di...
# 56244  2025-07-14  Makasih Kapten selalu hadir semoga membantu di...
#
# [13869 rows x 2 columns]

# %%
df_GOTO2 = df_GOTO.copy()

df_GOTO2['tanggal'] = pd.to_datetime(df_GOTO2['tanggal'], errors='coerce')

df_GOTO2['tahun'] = df_GOTO2['tanggal'].dt.year

# Hitung jumlah data per tahun
jumlah_per_tahun = df_GOTO2['tahun'].value_counts().sort_index()

# Tampilkan hasil
print(len(df_GOTO2))
print(jumlah_per_tahun)
# Out:
# 325080
# tahun
# 2015        43
# 2016       183
# 2017       169
# 2018       178
# 2019      1688
# 2020     43322
# 2021     74880
# 2022     31242
# 2023     27583
# 2024     41350
# 2025    104442
# Name: count, dtype: int64
