# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Skripsi
# Out:
# /content/drive/MyDrive/Skripsi

# %%
#@title Twitter Auth Token

twitter_auth_token = 'token login X' # change this auth token

# %%
# !npm install -g tweet-harvest
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠦npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠦npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# added 78 packages in 38s
# ⠹
# ⠹8 packages are looking for funding
# ⠹  run `npm fund` for details
# ⠹

# %%
# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,374 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,287 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# !npx playwright install-deps chromium
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏Need to install the following packages:
# playwright@1.57.0
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼Installing dependencies...
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
import os
import pandas as pd
import time
import shutil
import subprocess
from datetime import datetime, timedelta
from utils.data_collection import X_scrapping

# %%
TICKER = "GOTO"

output_dir = f'data/{TICKER}/data_collection'
log_dir = f'data/{TICKER}/data_collection/log_X'

# os.makedirs(output_dir, exist_ok=True)
# os.makedirs(log_dir, exist_ok=True)

# %% [markdown]
# #Start: 2022-07-10, End: 2025-07-31

# %%
# 🔧 Konfigurasi
search_keyword = "Gojek OR Tokopedia"
start_date = datetime(2025, 7, 26)
#end_date = datetime(2025, 1, 1)
end_date = start_date + timedelta(days=6)
batch_days = 1
batch_limit = 75
delay_seconds = 22

print(start_date)
print(end_date)
# Out:
# 2025-07-26 00:00:00
# 2025-08-01 00:00:00

# %%
X_scrapping(twitter_auth_token, search_keyword, start_date,
            end_date, output_dir, log_dir, TICKER, batch_days,
            batch_limit, delay_seconds)
# Out:
# 🚀 Menjalankan batch: 2025-07-26 → 2025-07-27
# ✅ Data Berhasil disimpan | Jumlah tweet: 79
#
# 🚀 Menjalankan batch: 2025-07-27 → 2025-07-28
# ✅ Data Berhasil disimpan | Jumlah tweet: 75
#
# 🚀 Menjalankan batch: 2025-07-28 → 2025-07-29
# ✅ Data Berhasil disimpan | Jumlah tweet: 63
#
# 🚀 Menjalankan batch: 2025-07-29 → 2025-07-30
# ✅ Data Berhasil disimpan | Jumlah tweet: 90
#
# 🚀 Menjalankan batch: 2025-07-30 → 2025-07-31
# ✅ Data Berhasil disimpan | Jumlah tweet: 71
#
# 🚀 Menjalankan batch: 2025-07-31 → 2025-08-01
# ✅ Data Berhasil disimpan | Jumlah tweet: 83
# Total sentimen baru yang didapatkan: 461

# %%
df_GOTO = pd.read_csv(f'{output_dir}/Full_X_comments_{TICKER}.csv')

# %%
len(df_GOTO)
# Out:
# 79174

# %%
df_GOTO.duplicated().sum()
# Out:
# np.int64(6410)
