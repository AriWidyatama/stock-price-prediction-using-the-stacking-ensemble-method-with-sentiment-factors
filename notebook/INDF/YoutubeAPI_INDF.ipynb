# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Skripsi
# Out:
# /content/drive/MyDrive/Skripsi

# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import pandas as pd
import json
import os
import time
from datetime import datetime
from utils.data_collection import main_youtube

# %%
API_KEY = 'Youtube API 3'
youtube = build('youtube', 'v3', developerKey=API_KEY)
TICKER = 'INDF'

# %%
output_dir = f'data/{TICKER}/data_collection'

# os.makedirs(output_dir, exist_ok=True)

USED_IDS_FILE = f'{output_dir}/id_indf.json'

# %%
query = "Indofood"

main_youtube(youtube, USED_IDS_FILE, query, TICKER)
# Out:
# Mencari video dengan query: 'Indofood'
# Video yang sudah pernah digunakan: 2576
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "quotaExceeded"
# Error saat mencari video: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/search?q=Indofood&part=snippet&type=video&maxResults=50&pageToken=CN4CEAA&relevanceLanguage=id&regionCode=ID&key=AIzaSyAF204BKFLUOBQLdCidtNvgjst8Nmvm6uo&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">
# ❌ Tidak ada video baru ditemukan.

# %%
df_INDF = pd.read_csv(f'{output_dir}/youtube_comments_{TICKER}.csv')

# %%
len(df_INDF)
# Out:
# 273833

# %%
df_INDF.duplicated().sum()
# Out:
# np.int64(14002)

# %%
df_INDF.isna().sum()
# Out:
# tanggal     0
# sentimen    6
# dtype: int64

# %%
df_INDF
# Out:
#           tanggal                                           sentimen
# 0      2019-02-24  contoh jika aku punya uang 120.000.000. 36 jut...
# 1      2025-07-05  Boikot toko dan produknya salim grup, yes. No ...
# 2      2025-06-24  Yg mau baikot harus asli impor dari Israel, ba...
# 3      2025-06-23                        terima kasih atas info nya,
# 4      2025-06-17                                                i ?
# ...           ...                                                ...
# 29187  2023-09-27                         Iya bener pait. Kapok dah😂
# 29188  2023-10-27  tumis bumbu nya blm mateng jga ngaruh bun... d...
# 29189  2023-11-25  Sepertinya emg pahit bun. Beda sm merk bamboe hhe
# 29190  2024-05-26  Kukira aku yg salah masak. Semur pun pait rasa...
# 29191  2024-12-28                               Ternyata sama pahit,
#
# [29192 rows x 2 columns]

# %%
df_INDF[df_INDF.duplicated(keep=False)].sort_values(by=['tanggal', 'sentimen'])
# Out:
#           tanggal                                           sentimen
# 19351  2017-02-13  +MakinPandai tapi apa ada kemungkinan di.dalem...
# 19356  2017-02-13  +MakinPandai tapi apa ada kemungkinan di.dalem...
# 19353  2017-02-13  +MakinPandai tapi kalo di matahari engga ada d...
# 19358  2017-02-13  +MakinPandai tapi kalo di matahari engga ada d...
# 19899  2017-02-13  +Ronaldo Yonathan Samson Mohon bersabar ini uj...
# ...           ...                                                ...
# 24474  2025-07-13  Lebih kejam mana dengan koruptor/maling uang r...
# 50378  2025-07-13  Saya udah coba....begitu muncul tekan 1,malah ...
# 77484  2025-07-13  Saya udah coba....begitu muncul tekan 1,malah ...
# 56242  2025-07-14  Makasih Kapten selalu hadir semoga membantu di...
# 56244  2025-07-14  Makasih Kapten selalu hadir semoga membantu di...
#
# [13869 rows x 2 columns]

# %%
df_INDF2 = df_INDF.copy()

df_INDF2['tanggal'] = pd.to_datetime(df_INDF2['tanggal'], errors='coerce')

df_INDF2['tahun'] = df_INDF2['tanggal'].dt.year

# Hitung jumlah data per tahun
jumlah_per_tahun = df_INDF2['tahun'].value_counts().sort_index()

# Tampilkan hasil
print(len(df_INDF2))
print(jumlah_per_tahun)
# Out:
# 163650
# tahun
# 2013        2
# 2014        1
# 2015        2
# 2016     1698
# 2017     1175
# 2018     2481
# 2019     3683
# 2020     4628
# 2021     7416
# 2022    10819
# 2023    20119
# 2024    65083
# 2025    46543
# Name: count, dtype: int64
